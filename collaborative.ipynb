# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

file_path = "/kaggle/input/clothing-fit-dataset-for-size-recommendation/renttherunway_final_data.json"
data = pd.read_json(file_path, lines=True)

df = pd.DataFrame(data)

# %%
df['category'].unique()
# Out:
# array(['romper', 'gown', 'sheath', 'dress', 'leggings', 'top', 'jumpsuit',
#        'sweater', 'jacket', 'shirtdress', 'maxi', 'shift', 'pants',
#        'shirt', 'mini', 'skirt', 'pullover', 'blouse', 'suit', 'coat',
#        'trench', 'bomber', 'cape', 'blazer', 'vest', 'duster', 'ballgown',
#        'tank', 'poncho', 'frock', 'tunic', 'cardigan', 'culottes', 'down',
#        'trouser', 'midi', 'pant', 'legging', 'print', 'knit', 'culotte',
#        'sweatshirt', 'peacoat', 'kaftan', 'overalls', 'jogger', 'tee',
#        'combo', 'henley', 'cami', 'blouson', 'turtleneck', 'trousers',
#        'overcoat', 'hoodie', 't-shirt', 'caftan', 'tight', 'kimono',
#        'for', 'crewneck', 'skirts', 'parka', 'buttondown', 'skort',
#        'sweatershirt', 'sweatpants', 'jeans'], dtype=object)

# %%
df['category'].nunique()
# Out:
# 68

# %%
def get_best_match(string, choices):
    return process.extractOne(string, choices)[0]

unique_categories = []

for category in df['category'].unique():
    if category not in unique_categories:
        similar_strings = [c for c in unique_categories if fuzz.ratio(category, c) >= 80]
        if similar_strings:
            for similar_string in similar_strings:
                df['category'] = df['category'].replace(similar_string, category)
        unique_categories.append(category)

# %%
df['category'].nunique()
# Out:
# 59

# %%
df['category'].unique()
# Out:
# array(['romper', 'gown', 'sheath', 'dress', 'legging', 'top', 'jumpsuit',
#        'sweater', 'jacket', 'shirtdress', 'maxi', 'skirts', 'pant',
#        'mini', 'pullover', 'blouse', 'suit', 'coat', 'trench', 'bomber',
#        'cape', 'blazer', 'vest', 'duster', 'ballgown', 'tank', 'poncho',
#        'frock', 'tunic', 'cardigan', 'culotte', 'down', 'trousers',
#        'midi', 'print', 'knit', 'sweatershirt', 'peacoat', 'caftan',
#        'overalls', 'jogger', 'tee', 'combo', 'henley', 'cami', 'blouson',
#        'turtleneck', 'overcoat', 'hoodie', 't-shirt', 'tight', 'kimono',
#        'for', 'crewneck', 'parka', 'buttondown', 'skort', 'sweatpants',
#        'jeans'], dtype=object)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         fit  user_id bust size  item_id  weight  rating     rented for  \
# 0       fit   420272       34d  2260466  137lbs    10.0       vacation
# 1       fit   273551       34b   153475  132lbs    10.0          other
# 3       fit   909926       34c   126335  135lbs     8.0  formal affair
# 4       fit   151944       34b   616682  145lbs    10.0        wedding
# 5       fit   734848       32b   364092  138lbs     8.0           date
# ...     ...      ...       ...      ...     ...     ...            ...
# 192539  fit    66386      34dd  2252812  140lbs    10.0           work
# 192540  fit   118398       32c   682043  100lbs    10.0           work
# 192541  fit    47002       36a   683251  135lbs     6.0       everyday
# 192542  fit   961120       36c   126335  165lbs    10.0        wedding
# 192543  fit   123612       36b   127865  155lbs    10.0        wedding
#
#                                               review_text          body type  \
# 0       An adorable romper! Belt and zipper were a lit...          hourglass
# 1       I rented this dress for a photo shoot. The the...  straight & narrow
# 3       I rented this for my company's black tie award...               pear
# 4       I have always been petite in my upper body and...           athletic
# 5       Didn't actually wear it. It fit perfectly. The...           athletic
# ...                                                   ...                ...
# 192539                                  Fit like a glove!          hourglass
# 192540  The pattern contrast on this dress is really s...             petite
# 192541  Like the other DVF wraps, the fit on this is f...  straight & narrow
# 192542  This dress was PERFECTION.  it looked incredib...               pear
# 192543  This dress was wonderful! I had originally pla...           athletic
#
#                                            review_summary  category height  \
# 0                                    So many compliments!    romper  5' 8"
# 1                                 I felt so glamourous!!!      gown  5' 6"
# 3        Dress arrived on time and in perfect condition.      dress  5' 5"
# 4                         Was in love with this dress !!!      gown  5' 9"
# 5                         Traditional with a touch a sass     dress  5' 8"
# ...                                                   ...       ...    ...
# 192539       LOVE IT!!! First Item Im thinking of buying!  jumpsuit  5' 9"
# 192540                                           LOVE it!     dress  5' 1"
# 192541                    Loud patterning, flattering fit     dress  5' 8"
# 192542  loved this dress it was comfortable and photog...     dress  5' 6"
# 192543  I wore this to a beautiful black tie optional ...      gown  5' 6"
#
#         size   age         review_date
# 0         14  28.0      April 20, 2016
# 1         12  36.0       June 18, 2013
# 3          8  34.0   February 12, 2014
# 4         12  27.0  September 26, 2016
# 5          8  45.0      April 30, 2016
# ...      ...   ...                 ...
# 192539     8  42.0        May 18, 2016
# 192540     4  29.0  September 30, 2016
# 192541     8  31.0       March 4, 2016
# 192542    16  31.0   November 25, 2015
# 192543    16  30.0     August 29, 2017
#
# [146381 rows x 15 columns]

# %%
df['height_inches'] = df['height'].apply(lambda x: int(x.split("'")[0]) * 12 + int(x.split("'")[1].replace('"', '')))

# convert into inches 

# Convert weight to numeric values
df['weight_lbs'] = df['weight'].apply(lambda x: int(x.replace('lbs', '')))

# Group by item_id 
product_df = df.groupby('item_id').agg({
    'review_text': lambda x: ' '.join(x),
    'review_summary': lambda x: ' '.join(x),
    'height_inches': 'mean',
    'weight_lbs': 'mean',
    'age': 'mean',
    'rating': 'mean', 
    'rented for': lambda x: ', '.join(x.unique()) 
}).reset_index()


product_df.rename(columns={'height_inches': 'avg_height', 'weight_lbs': 'avg_weight', 'age': 'avg_age', 'rating': 'avg_rating'}, inplace=True)

# %%
product_df

# product_df.to_excel('product_df.xlsx', index=False)
# Out:
#       item_id                                        review_text  \
# 0      123373  The dress was beautiful and very comfortable. ...
# 1      123793  Fit great, super flattering Limited range of a...
# 2      124204  This dress is a "WOW."  It steals the show, sp...
# 3      124553  Loved the dress.  A little short in the front ...
# 4      125424  The dress would have been perfect in a size 10...
# ...       ...                                                ...
# 5731  2963850  This skirt is super cute. The waistline hits a...
# 5732  2964470  I loved this sweater from Tory Burch. I didn't...
# 5733  2965009  This fur coat was SO fun to wear, and actually...
# 5734  2965924  I ordered a size 10 and should have gone down ...
# 5735  2966087  I am so in love with these pants! So comfy and...
#
#                                          review_summary  avg_height  \
# 0     It was a very beautiful black tie wedding I lo...   65.297189
# 1     Stunning gown. Wore this for heart ball and re...   65.050222
# 2     When I opened the RTR box and saw these sequin...   65.090909
# 3     Lovely wedding guest dress Fabulous! Added a b...   65.450000
# 4     I didn't wear it but it would have been perfec...   65.680672
# ...                                                 ...         ...
# 5731  I wore this to work I was not able to wear the...   64.250000
# 5732  perfect sweater! Looks professional and dressy...   61.666667
# 5733  omg so fun Nothing makes me feel more bad*** t...   66.000000
# 5734  So many compliments on this piece. Really beau...   65.000000
# 5735  FAVORITE PANTS EVER! Versatile and stylish  My...   65.500000
#
#       avg_weight    avg_age  avg_rating  \
# 0     141.108434  35.178715    8.871486
# 1     132.706056  31.671344    9.528804
# 2     137.614876  33.800000    9.325620
# 3     139.655556  33.211111    8.527778
# 4     136.683473  32.742297    9.025210
# ...          ...        ...         ...
# 5731  134.875000  29.625000    9.750000
# 5732  153.333333  38.333333   10.000000
# 5733  123.666667  34.000000    9.333333
# 5734  141.333333  43.000000    9.333333
# 5735  136.500000  34.750000    8.500000
#
#                                              rented for
# 0     wedding, formal affair, party, other, vacation...
# 1      formal affair, wedding, other, party, date, work
# 2     formal affair, party, other, wedding, vacation...
# 3     wedding, other, work, formal affair, date, par...
# 4     wedding, party, other, formal affair, date, va...
# ...                                                 ...
# 5731                              everyday, other, work
# 5732                                     everyday, work
# 5733                           date, everyday, vacation
# 5734                                  other, work, date
# 5735                              party, work, everyday
#
# [5736 rows x 8 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
import numpy as np


product_df['combined_text'] = product_df['review_text'] + ' ' + product_df['review_summary']


scaler = StandardScaler()
product_df['normalized_rating'] = scaler.fit_transform(product_df['avg_rating'].values.reshape(-1, 1))


tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix_text = tfidf_vectorizer.fit_transform(product_df['combined_text'])
tfidf_matrix_rating = product_df['normalized_rating'].values.reshape(-1, 1)


tfidf_matrix_combined = np.hstack([tfidf_matrix_text.toarray(), tfidf_matrix_rating])


item_item_similarity = cosine_similarity(tfidf_matrix_combined, tfidf_matrix_combined)

# Example: Get top 5 similar items for item_id 1
item_id = 1
similar_items_indices = item_item_similarity[item_id].argsort()[::-1][1:6]

# Get the product details for similar items
similar_items = product_df.iloc[similar_items_indices]

print(similar_items)
# Out:
#       item_id                                        review_text  \
# 1299   755371  I got a size 6r and 8r just in case the dress ...
# 10     127865  The dress had a lot of stretch so it made it  ...
# 2847  1515339  Loved it. RTR helped me pick this out after th...
# 1210   709832  This dress was PERFECT for the event.  I've re...
# 1456   834620  The 4L was perfect for my height wearing 3 inc...
#
#                                          review_summary  avg_height  \
# 1299  I wore this dress for my senior prom and it wa...   65.254125
# 10    We had so much fun and the American Heart Asso...   65.130824
# 2847  This. Dress. Is. Amazing.  **  This gown is ep...   65.323529
# 1210  This dress was absolutely PERFECT.  Got compli...   65.187500
# 1456  Looked fantastic! Great dress! Comfortable, so...   65.520833
#
#       avg_weight    avg_age  avg_rating  \
# 1299  134.438944  31.828383    9.425743
# 10    136.253584  36.959677    9.446237
# 2847  133.522059  29.970588    9.544118
# 1210  135.000000  36.777778    9.805556
# 1456  138.197917  33.750000    9.687500
#
#                                             rented for  \
# 1299        formal affair, wedding, other, party, date
# 10    formal affair, wedding, other, party, date, work
# 2847              wedding, formal affair, party, other
# 1210        formal affair, date, wedding, party, other
# 1456        formal affair, wedding, party, other, work
#
#                                           combined_text  normalized_rating
# 1299  I got a size 6r and 8r just in case the dress ...           0.537912
# 10    The dress had a lot of stretch so it made it  ...           0.563050
# 2847  Loved it. RTR helped me pick this out after th...           0.683112
# 1210  This dress was PERFECT for the event.  I've re...           1.003795
# 1456  The 4L was perfect for my height wearing 3 inc...           0.858986

# %% [markdown]
# #### KNN

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
import re

def convert_height(height):
    match = re.match(r"(\d+)' (\d+)\"", height)
    if match:
        feet = int(match.group(1))
        inches = int(match.group(2))
        return feet * 12 + inches
    else:
        return None

df['height'] = df['height'].apply(convert_height)

def extract_numeric(text):
    if isinstance(text, str):
        match = re.match(r'(\d+)', text)
        if match:
            return float(match.group(1))
    return text

df['weight'] = df['weight'].apply(extract_numeric)

features = ['bust size', 'weight', 'height', 'size', 'age', 'body type', 'rating']
target = 'item_id'

numeric_features = ['weight', 'height', 'size', 'age']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['bust size', 'body type']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

X = df[features]
y = df[target]
X_preprocessed = pipeline.fit_transform(X)

k = 5  
knn_model = NearestNeighbors(n_neighbors=k, metric='euclidean') 
knn_model.fit(X_preprocessed)

def recommend_items(new_user_features):
    new_user_features_preprocessed = pipeline.transform(pd.DataFrame([new_user_features]))
    distances, indices = knn_model.kneighbors(new_user_features_preprocessed)
    valid_indices = indices[0][indices[0] < len(df)]
    recommended_items = df.iloc[valid_indices][target]
    return recommended_items


new_user_features = {'bust size': '34C', 'weight': 130, 'height': 65, 'size': 8, 'age': 30, 'body type': 'hourglass', 'rating': 5}
recommended_items = recommend_items(new_user_features)
print('User_id   Item_id')
print(recommended_items)
# Out:
# User_id   Item_id
# 92907     2283350
# 66618     2653183
# 139948     158028
# 189120    2307629
# 119786    1126889
# Name: item_id, dtype: int64

# %%
product_ratings1 = df.head(10000)
ratings_utility_matrix = product_ratings1.pivot_table(values='rating', index='user_id', columns='item_id', fill_value=0)
X = ratings_utility_matrix.T
X.head()
# Out:
# user_id  321     329     331     611     635     657     678     772     \
# item_id
# 123373        0       0       0       0       0       0       0       0
# 123793        0       0       0       0       0       0       0       0
# 124204        0       0       0       0       0       0       0       0
# 124553        0       0       0       0       0       0       0       0
# 125424        0       0       0       0       0       0       0       0
#
# user_id  1066    1070    ...  998704  999016  999063  999183  999274  999552  \
# item_id                  ...
# 123373        0       0  ...       0       0       0       0       0       0
# 123793        0       0  ...       0       0       0       0       0       0
# 124204        0       0  ...       0       0       0       0       0       0
# 124553        0       0  ...       0       0       0       0       0       0
# 125424        0       0  ...       0       0       0       0       0       0
#
# user_id  999621  999726  999910  999913
# item_id
# 123373        0       0       0       0
# 123793        0       0       0       0
# 124204        0       0       0       0
# 124553        0       0       0       0
# 125424        0       0       0       0
#
# [5 rows x 8889 columns]

# %% [markdown]
# ## SVD

# %%
from sklearn.decomposition import TruncatedSVD

SVD = TruncatedSVD(n_components=50)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (3136, 50)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (3136, 3136)

# %%
def get_product_row(df, product_id):
    product_row = df[df['item_id'] == product_id] 
    return product_row

i=148089

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID

print(get_product_row(df,i))
# Out:
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 223       fit   606812       32d   148089   132.0    10.0        wedding
# 643     small   845469       34b   148089   154.0     6.0  formal affair
# 841       fit   747133       32a   148089   110.0    10.0        wedding
# 1003      fit   857032       32c   148089   118.0    10.0        wedding
# 3184      fit   164355       34d   148089   140.0    10.0  formal affair
# ...       ...      ...       ...      ...     ...     ...            ...
# 187711    fit   851114       34b   148089   115.0    10.0  formal affair
# 189703    fit   860698       36c   148089   150.0    10.0        wedding
# 190731    fit   562629       36d   148089   160.0     8.0           date
# 190776  small   524706       36c   148089   139.0     8.0          other
# 191652    fit   393231       36d   148089   165.0    10.0        wedding
#
#                                               review_text          body type  \
# 223     I rented this dress and the same dress in blue...          hourglass
# 643     I liked this dress because it opened up at the...               pear
# 841     I am 5'5 and the dress hit me right at the kne...  straight & narrow
# 1003    The color was more vibrant in person, which wa...  straight & narrow
# 3184    I loved this dress!  I wore it to a fundraiser...           athletic
# ...                                                   ...                ...
# 187711  Rented this for a charity event and it couldn'...          hourglass
# 189703  The dress fit well, the only issue I had was w...              apple
# 190731  I wore this dress the night that my now fiancé...          hourglass
# 190776  I wore this to a women's conference (I got to ...          hourglass
# 191652  I was worried this dress would be to short - b...          hourglass
#
#                                            review_summary category  height  \
# 223                    Beautiful color and beautiful fit.    dress      64
# 643             Beautiful dress but a little constricting    dress      68
# 841     Great dress, perfect fit, and amazing color! I...    dress      65
# 1003    I have never received so many compliments on a...    dress      66
# 3184                                               Loved!    dress      66
# ...                                                   ...      ...     ...
# 187711                              Better than your LBD!    dress      66
# 189703  I wore this to my sister's rehearsal dinner an...    dress      66
# 190731  Beautiful fit, gorgeous color - though more pu...    dress      66
# 190776  I LOVE this color, and the nude underlay pairs...    dress      62
# 191652     This dress was amazing! Perfect color and fit!    dress      68
#
#         size   age        review_date  height_inches  weight_lbs
# 223        8  31.0   January 31, 2015             64         132
# 643       12  31.0  September 2, 2014             68         154
# 841        1  25.0   October 26, 2014             65         110
# 1003       4  30.0     March 18, 2015             66         118
# 3184      16  46.0      March 2, 2014             66         140
# ...      ...   ...                ...            ...         ...
# 187711     8  35.0  February 17, 2014             66         115
# 189703    20  32.0      March 2, 2014             66         150
# 190731    24  36.0   January 14, 2015             66         160
# 190776    24  30.0     April 17, 2015             62         139
# 191652    20  30.0      April 7, 2014             68         165
#
# [308 rows x 17 columns]

# %% [markdown]
# ## K-means Clustering for users

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# Load data
# product_descriptions = pd.read_json('renttherunway_final_data.json', lines=True)
product_descriptions1 = df.head(500)

# Vectorize product descriptions
vectorizer = TfidfVectorizer(stop_words='english')
X_product = vectorizer.fit_transform(product_descriptions1["review_text"])

# K-means clustering on product descriptions
kmeans_product = KMeans(n_clusters=10, init='k-means++')
kmeans_product.fit(X_product)

# Extract product IDs and cluster indices
product_ids = product_descriptions1["item_id"].values
product_cluster_indices = kmeans_product.labels_


user_data = product_descriptions1[['age', 'size','weight','height']].fillna(0)  # Filling NaNs with 0 for simplicity

# K-means clustering on user data
kmeans_user = KMeans(n_clusters=5, init='k-means++')
kmeans_user.fit(user_data)

# Recommend 5 products to a new user
def recommend_products(new_user_data, num_recommendations=5):
    # Convert new_user_data dictionary to a list
    new_user_data_list = [new_user_data['age'], new_user_data['size'],new_user_data['weight'], new_user_data['height']]
    # Predict the cluster for the new user
    user_cluster = kmeans_user.predict([new_user_data_list])[0]
    # Find products belonging to the same cluster as the user
    cluster_products = product_ids[kmeans_user.labels_ == user_cluster]
    # Randomly select 5 products from the cluster for recommendation
    recommended_products = np.random.choice(cluster_products, size=num_recommendations, replace=False)
    return recommended_products

# Example usage:
new_user_data = {'age': 25, 'size': 8,'weight':130,'height':72}  # New user's age and size
recommended_products = recommend_products(new_user_data, num_recommendations=5)
print("Recommended Product IDs:", recommended_products)
# Out:
# Recommended Product IDs: [ 806803 2608150  181453 1212992  442171]
# /opt/conda/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   "X does not have valid feature names, but"

# %%
correlation_product_ID = correlation_matrix[product_ID]
Recommend = list(X.index[correlation_product_ID > 0.60])

Recommend.remove(i)

Recommend = Recommend[:9]

for product_index in Recommend:
    ans = get_product_row(df, product_index)
    print(ans)
# Out:
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 2546    small   446593       34c   129831   125.0    10.0        wedding
# 4477      fit   470049       32d   129831   115.0    10.0          other
# 4556    small   509263       34d   129831   150.0    10.0  formal affair
# 5939    small   478800       34a   129831   133.0     8.0        wedding
# 6141    small   723099       32c   129831   120.0     8.0        wedding
# ...       ...      ...       ...      ...     ...     ...            ...
# 189097    fit   112150       34c   129831   118.0    10.0        wedding
# 190107    fit   642220       32a   129831   102.0    10.0          party
# 190250    fit   129263       34d   129831   130.0    10.0        wedding
# 190950    fit   302599      32aa   129831    95.0    10.0          party
# 192447    fit   450455       36d   129831   118.0    10.0        wedding
#
#                                               review_text  body type  \
# 2546    I rented this for a wedding in July in VA. It ...  hourglass
# 4477    I wore this dress to a baptism and it was perf...     petite
# 4556    This dress was definitely fitted and more of a...  hourglass
# 5939    I was very glad I read the ratings on this one...   athletic
# 6141    I originally rented the 2 as my main size, but...   athletic
# ...                                                   ...        ...
# 189097  This is a gorgeous dress which is well made.  ...   athletic
# 190107  Perfect cut and length for small-boned and sma...     petite
# 190250  The dress was beautiful and fit true to size. ...  hourglass
# 190950  well fitted without being too tight. the arms ...     petite
# 192447  I loved the dress!! I was a bit afraid it woul...     petite
#
#                                   review_summary category  height  size   age  \
# 2546                Flattering semi-formal dress    dress      60    12  24.0
# 4477         Would totally recommend this dress!    dress      63     1  24.0
# 4556                Elegant but not crazy formal    dress      66    16  27.0
# 5939                            Size up for arms    dress      66    12  30.0
# 6141    Beautiful Wedding in Unforgettable Space    dress      62     8  27.0
# ...                                          ...      ...     ...   ...   ...
# 189097                           Beautiful Color    dress      64     1  40.0
# 190107        Lovely dress for an office party.     dress      61     1  42.0
# 190250           Great dress for a fall wedding!    dress      64    12  30.0
# 190950           unique color and beautiful lace    dress      60     1  37.0
# 192447                          The dress!!!!!!!    dress      63     4  22.0
#
#               review_date  height_inches  weight_lbs
# 2546        July 17, 2017             60         125
# 4477     February 3, 2015             63         115
# 4556        March 7, 2014             66         150
# 5939        June 12, 2016             66         133
# 6141    December 17, 2014             62         120
# ...                   ...            ...         ...
# 189097  November 24, 2013             64         118
# 190107  February 20, 2014             61         102
# 190250   November 5, 2014             64         130
# 190950      June 11, 2017             60          95
# 192447   October 10, 2017             63         118
#
# [169 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 154     large   299660      38dd   141761   180.0     6.0  formal affair
# 540       fit   871911       32c   141761   135.0     6.0        wedding
# 941     large   890641       34b   141761   135.0    10.0           date
# 1941      fit   236358       34d   141761   120.0    10.0        wedding
# 5639      fit   768140       34c   141761   140.0    10.0        wedding
# ...       ...      ...       ...      ...     ...     ...            ...
# 187919  large   100311       34b   141761   144.0     8.0        wedding
# 188231    fit   275128       36b   141761   165.0     8.0          party
# 191290    fit   209853       34d   141761   150.0     8.0          other
# 191297  large    27392       34a   141761   130.0     8.0  formal affair
# 191612  large   367566       32c   141761   115.0    10.0        wedding
#
#                                               review_text  body type  \
# 154     This was my backup dress and I didn't need to ...  hourglass
# 540     I rented both the 0 and the 2, and while the 0...   athletic
# 941     Definitely a bit on the large side so I ordere...     petite
# 1941    Fit was true to size, I could wear a regular b...  hourglass
# 5639    Rented this dress for an out of town wedding. ...  hourglass
# ...                                                   ...        ...
# 187919  I loved this dress and received numerous compl...       pear
# 188231  This dress fits true to size.  I normally wear...       pear
# 191290  I tried this dress on at the NYC Henri Bendel ...       pear
# 191297  It fit well but I went down a size. Very comfo...       pear
# 191612  A little big at the bust, but nothing a padded...     petite
#
#                                            review_summary category  height  \
# 154                   Runs large- very full in the belly.    dress      67
# 540                        Gorgeous Colour, annoying fit.    dress      69
# 941                               Cute dress with pockets    dress      64
# 1941                  Compliments all night on this dress    dress      63
# 5639                           Beautiful color + pockets!    dress      70
# ...                                                   ...      ...     ...
# 187919        Gorgeous dress, but very roomy in the waist    dress      68
# 188231  This cocktail party was in midtown Manhattan o...    dress      63
# 191290                                 Showroom discovery    dress      63
# 191297  Lovely fabric and easy to wear. I usually wear...    dress      65
# 191612                     Perfect for an Indian wedding     dress      63
#
#         size   age         review_date  height_inches  weight_lbs
# 154       24  39.0    October 15, 2013             67         180
# 540        4  32.0     October 1, 2014             69         135
# 941        8  33.0        June 9, 2015             64         135
# 1941       8  28.0      April 27, 2015             63         120
# 5639      12  35.0   December 15, 2015             70         140
# ...      ...   ...                 ...            ...         ...
# 187919     8  35.0    December 1, 2014             68         144
# 188231    16  43.0       July 23, 2015             63         165
# 191290     8  41.0  September 24, 2014             63         150
# 191297     8  52.0       March 3, 2016             65         130
# 191612     1  31.0   September 7, 2014             63         115
#
# [228 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 517       fit   502689      34d+   155381   120.0     8.0  formal affair
# 1213      fit   215055       36c   155381   155.0    10.0  formal affair
# 3161      fit   674058       36b   155381   150.0     8.0          party
# 3529      fit   816981       34b   155381   140.0     4.0        wedding
# 4601      fit   546141       32d   155381   127.0    10.0          party
# ...       ...      ...       ...      ...     ...     ...            ...
# 184260    fit   125434       32b   155381   112.0    10.0        wedding
# 187012    fit    37692       32b   155381   125.0    10.0        wedding
# 188974  large    91719       36b   155381   190.0    10.0           date
# 190633    fit   401024       32b   155381   113.0    10.0           work
# 192201    fit   217963       36c   155381   175.0    10.0          party
#
#                                               review_text          body type  \
# 517     I wore this to my sorority formal and I LOVED ...          hourglass
# 1213    The only con I have for this dress was that th...          hourglass
# 3161    Pros: I liked the overall fit of the dress, I ...           athletic
# 3529    Cute dress, but it looks different on the site...          hourglass
# 4601                   Fit great and was very flattering!             petite
# ...                                                   ...                ...
# 184260  This dress is so comfortable! Great quality an...  straight & narrow
# 187012                  Fit true to size. Beautiful color           athletic
# 188974       This dress made me feel beautiful all night!               pear
# 190633  The fit was true to size. Very comfortable and...             petite
# 192201  The 8 and the 10 both fit, as there is some st...           athletic
#
#                                            review_summary category  height  \
# 517     My roommates were in love with this dress: the...    dress      60
# 1213    LOVED IT! Fit great (the length was perfect) a...    dress      69
# 3161                                     Fun Winter Dress    dress      70
# 3529                                           good color    dress      66
# 4601          Got tons of compliments!!! Love this dress.    dress      62
# ...                                                   ...      ...     ...
# 184260                                      Perfect Dress    dress      65
# 187012                         Loved the dress, great fit    dress      66
# 188974                Gorgeous color, Flirty and feminine    dress      62
# 190633                          Such a comfortable dress!    dress      63
# 192201  This dress is easy to wear.  The material is t...    dress      68
#
#         size   age        review_date  height_inches  weight_lbs
# 517        8  25.0  November 28, 2013             60         120
# 1213      12  21.0  February 22, 2015             69         155
# 3161      12  30.0  December 15, 2014             70         150
# 3529       8  32.0       July 4, 2014             66         140
# 4601      12  34.0     March 16, 2014             62         127
# ...      ...   ...                ...            ...         ...
# 184260     1  32.0     April 15, 2014             65         112
# 187012     4  29.0      March 3, 2014             66         125
# 188974    16  30.0        May 6, 2014             62         190
# 190633     1  27.0   December 2, 2016             63         113
# 192201    20  29.0   December 9, 2014             68         175
#
# [115 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 206       fit   107270       34d   156607   160.0     8.0          party
# 1523      fit   430291       34a   156607   120.0     8.0          party
# 4653      fit   860981       38b   156607   180.0     8.0          other
# 6840    small   497682      36d+   156607   160.0     8.0        wedding
# 10573     fit   586317       32d   156607   125.0     8.0        wedding
# ...       ...      ...       ...      ...     ...     ...            ...
# 185841    fit   271586       34b   156607   108.0    10.0        wedding
# 186622  small   451063       34b   156607   140.0    10.0          party
# 189660  large   587005      32d+   156607   145.0    10.0  formal affair
# 191856    fit   975136       34b   156607   145.0     8.0  formal affair
# 192347    fit     4894       32d   156607   125.0     8.0          party
#
#                                               review_text  body type  \
# 206     I wore this dress for my schools winter gala, ...  hourglass
# 1523    I wore this dress to a Sweet 16 and it fit ver...     petite
# 4653    Overall fit was great, only downfall were that...       pear
# 6840    I had to use the larger size due to my bust si...  hourglass
# 10573   First let me say the straps were LONG. If I ha...  full bust
# ...                                                   ...        ...
# 185841   Great color, true to size, and very comfortable.     petite
# 186622  The fit was great for my hourglass shape - sma...  hourglass
# 189660  The dress was great! It's simple but beautiful...  hourglass
# 191856  I have very broad shoulders and this dress fit...   athletic
# 192347  I rented this for my 12-year old daughter for ...     petite
#
#                                            review_summary category  height  \
# 206     I loved this dress, it had a beautiful pattern...    dress      66
# 1523           Fun and pretty, but the straps kept fallng    dress      64
# 4653                                     First homecoming    dress      68
# 6840    This was a formal optional wedding and this dr...    dress      69
# 10573                     Such a fun dress for a wedding!    dress      64
# ...                                                   ...      ...     ...
# 185841  The dress was beautiful! Received a lot of com...    dress      62
# 186622  Beautiful fabric and pockets made this a stand...    dress      63
# 189660                                   Beautiful Dress!    dress      68
# 191856  This dress was exactly what I was looking for ...    dress      68
# 192347        Very cute for a younger woman - long straps    dress      59
#
#         size   age         review_date  height_inches  weight_lbs
# 206       20  20.0   February 26, 2016             66         160
# 1523       1  47.0   December 16, 2014             64         120
# 4653      16  46.0  September 29, 2014             68         180
# 6840      20  43.0      April 26, 2015             69         160
# 10573      4  28.0  September 23, 2013             64         125
# ...      ...   ...                 ...            ...         ...
# 185841     8  27.0        May 21, 2017             62         108
# 186622    20  33.0   February 16, 2016             63         140
# 189660    12  25.0   February 25, 2015             68         145
# 191856    12  34.0   November 24, 2017             68         145
# 192347    16  49.0     January 9, 2017             59         125
#
# [101 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 3040      fit   936363       32b   165468   125.0    10.0          party
# 5022    large   293381       34d   165468   150.0    10.0          party
# 6505    large   677159       36c   165468   140.0     8.0  formal affair
# 9632    large   641357       32b   165468   165.0    10.0          party
# 10231   large   386608       34b   165468   128.0     8.0          party
# ...       ...      ...       ...      ...     ...     ...            ...
# 180772  large   389840       32b   165468   100.0     8.0  formal affair
# 187643    fit   512647       32d   165468   130.0    10.0        wedding
# 188817    fit   934506       38d   165468   192.0     8.0          party
# 188887    fit   497025       34c   165468   128.0    10.0          party
# 188964  large    52584       34d   165468   150.0     6.0          party
#
#                                               review_text          body type  \
# 3040    I loved the fit! I loved the dress in general!...  straight & narrow
# 5022    loose fitting - i got the size 6 and 8 and pic...          hourglass
# 6505    Dress fit well overall. Was a little big with ...          full bust
# 9632    The dress was comfortable and sparkly. A great...               pear
# 10231   Super comfy!  Got lots of compliments.  Loved ...               pear
# ...                                                   ...                ...
# 180772  This dress was stunning. I loved how it caught...             petite
# 187643  I wore this dress to an evening wedding in NYC...               pear
# 188817  The only thing I disliked about this dress was...          full bust
# 188887  Pictures do this dress no justice. Got this fo...          hourglass
# 188964  Unfortunately, I actually did not wind up wear...          hourglass
#
#                                            review_summary category  height  \
# 3040    I wore this dress to my 1920's themed homecomi...    dress      70
# 5022          perfect for a gatsby themed birthday party!    dress      62
# 6505    Got so many compliments on this dress! It was ...    dress      60
# 9632                                     My bachelorette!    dress      70
# 10231          Perfect for the Great Gatsby themed party!    dress      64
# ...                                                   ...      ...     ...
# 180772                                  LOVED this dress!    dress      62
# 187643  The dress was a big hit - I received lots of c...    dress      62
# 188817                                                  .    dress      65
# 188887                                 The Sparkle Tho...    dress      63
# 188964                      Beautiful dress for going out    dress      66
#
#         size   age       review_date  height_inches  weight_lbs
# 3040       4  20.0  October 21, 2013             70         125
# 5022      12  32.0    August 5, 2014             62         150
# 6505       8  31.0  November 7, 2012             60         140
# 9632       8  36.0      May 26, 2016             70         165
# 10231      4  38.0     June 23, 2014             64         128
# ...      ...   ...               ...            ...         ...
# 180772     1  29.0   October 3, 2014             62         100
# 187643     8  40.0  January 13, 2013             62         130
# 188817    20  29.0    April 28, 2013             65         192
# 188887     8  40.0      June 5, 2017             63         128
# 188964     8  32.0    August 6, 2014             66         150
#
# [70 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 141       fit   790516       32c   167112   120.0    10.0        wedding
# 1164      fit   804752       34d   167112   130.0    10.0        wedding
# 1993      fit   786103       34d   167112   137.0    10.0        wedding
# 3371      fit   709728       32a   167112   115.0     8.0        wedding
# 3740      fit   965082       36b   167112   150.0    10.0  formal affair
# ...       ...      ...       ...      ...     ...     ...            ...
# 185348    fit   928441       34d   167112   140.0    10.0        wedding
# 186333    fit   142954       34c   167112   140.0     8.0        wedding
# 188109    fit   889153       36c   167112   135.0    10.0  formal affair
# 189072  small   198722       36d   167112   145.0     8.0          party
# 190385    fit   900010       32d   167112   155.0    10.0        wedding
#
#                                               review_text          body type  \
# 141     This dress is LOVELY. I rented it for a hip ye...               pear
# 1164    Had to wear the larger size (I rented a 6 and ...           athletic
# 1993    Fit true to size had an extra clasp on bust so...          hourglass
# 3371    This dress,overall, was a hit.  I will say tho...             petite
# 3740    This dress looked awesome! This was for a work...           athletic
# ...                                                   ...                ...
# 185348  This was my first time using RTR - I loved thi...              apple
# 186333  I ordered this as a backup but wound up not we...          hourglass
# 188109  Loved the dress! It was fitted but still class...  straight & narrow
# 189072  Dress was gorgeous, the sizing just ran a litt...          full bust
# 190385  I loved the fit of this dress! It was forgivin...               pear
#
#                                            review_summary category  height  \
# 141     Unique and delicate fit // beautiful lace deta...    dress      67
# 1164               Felt great in this classic lace dress!    dress      62
# 1993    Dress came right on time and it was in perfect...    dress      65
# 3371          Super classy and cute - tons of compliments    dress      60
# 3740    Loved getting to wear a gorg Shoshanna dress f...    dress      67
# ...                                                   ...      ...     ...
# 185348      Wore this to a wedding.  Lots of compliments.    dress      63
# 186333                          Pretty but didn't wear it    dress      67
# 188109                 Great experience! Loved the dress.    dress      69
# 189072       How easy it was to get a dress for my event.    dress      65
# 190385                                   wish I owned it!    dress      67
#
#         size   age         review_date  height_inches  weight_lbs
# 141        4  36.0   November 12, 2013             67         120
# 1164      16  37.0       July 15, 2015             62         130
# 1993       8  34.0    October 22, 2014             65         137
# 3371       1  32.0    October 20, 2014             60         115
# 3740      20  29.0       June 11, 2014             67         150
# ...      ...   ...                 ...            ...         ...
# 185348    16  36.0  September 30, 2014             63         140
# 186333    16  33.0  September 23, 2014             67         140
# 188109    12  28.0   December 17, 2013             69         135
# 189072    16  33.0    January 25, 2014             65         145
# 190385    16  27.0       June 22, 2016             67         155
#
# [125 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating rented for  \
# 787       fit   130782       34d   183945   130.0    10.0      party
# 1752      fit   635302       34b   183945   115.0    10.0      other
# 1944      fit   452768       36d   183945   127.0    10.0    wedding
# 4774      fit   803284       32b   183945   120.0     8.0      other
# 5493    small   837666       32b   183945   110.0     8.0      other
# ...       ...      ...       ...      ...     ...     ...        ...
# 184866  large   984614       36d   183945   130.0     8.0      other
# 185122    fit   765903       32c   183945   105.0    10.0      party
# 185359    fit   432479       34b   183945   134.0     6.0      other
# 186150  small   547743       32a   183945    98.0    10.0    wedding
# 192173    fit   234649       34c   183945   110.0    10.0      other
#
#                                               review_text  body type  \
# 787     It wore the smaller of the size for a tighter ...   athletic
# 1752    The coloring of this dress is so unique and th...  hourglass
# 1944    Wore this dress for an afternoon wedding. It w...  full bust
# 4774    I'm 5'8'', so I found the dress to be on the s...       pear
# 5493    I wore the dress to my graduation and received...   athletic
# ...                                                   ...        ...
# 184866  The dress is short, but I wore it with ballet ...  hourglass
# 185122  It was a little loose in the mid section, but ...     petite
# 185359  pros: nice color\ncons: sleeve length is odd, ...       pear
# 186150  This dress fit perfectly.  I received compleme...     petite
# 192173  This dress is gorgeous! It fits pretty straigh...     petite
#
#                                            review_summary category  height  \
# 787     Everyone loved my dress. Randos came up to me ...   sheath      64
# 1752                                Love the lace detail!   sheath      67
# 1944                           Super comfy!! Great color!   sheath      62
# 4774                Perfect for my sister's bridal shower   sheath      68
# 5493              The dress was classy, elegant, and hot!   sheath      62
# ...                                                   ...      ...     ...
# 184866  Brilliant color and lace that was perfect for ...   sheath      66
# 185122  Perfect for a Bachtelorette party at the Phoen...   sheath      64
# 185359       Okay not great. Expensive for what you get.    sheath      67
# 186150                             Great for Petite Girls   sheath      60
# 192173                                    Love the color!   sheath      60
#
#         size   age        review_date  height_inches  weight_lbs
# 787        8  40.0   October 29, 2012             64         130
# 1752       4  28.0   October 23, 2012             67         115
# 1944      16  33.0     April 11, 2014             62         127
# 4774       8  28.0  December 27, 2015             68         120
# 5493       8  35.0       May 21, 2013             62         110
# ...      ...   ...                ...            ...         ...
# 184866    12  34.0     April 16, 2014             66         130
# 185122     4  37.0   February 3, 2014             64         105
# 185359    12  35.0  November 11, 2012             67         134
# 186150     4  33.0       July 2, 2013             60          98
# 192173     8  34.0     April 20, 2014             60         110
#
# [116 rows x 17 columns]
#           fit  user_id bust size  item_id  weight  rating     rented for  \
# 12254     fit   522429       34d   247125   145.0     8.0          party
# 17022     fit    14015       36c   247125   165.0    10.0          party
# 22418     fit   477812      36dd   247125   180.0    10.0           date
# 26090     fit    68369       34b   247125   155.0    10.0          other
# 38891     fit   843376       32b   247125   130.0    10.0  formal affair
# 39212     fit   499514      34d+   247125   155.0     8.0        wedding
# 47674   large   792838       36b   247125   145.0    10.0          party
# 52220     fit     4245       34c   247125   135.0    10.0          party
# 56636   small   284501       34c   247125   150.0     8.0          party
# 58304   small   472209       36b   247125   160.0    10.0        wedding
# 59810     fit   990544       36b   247125   134.0     6.0          party
# 61591     fit    26383       34c   247125   148.0     8.0           date
# 62800     fit   664868       34c   247125   115.0    10.0          party
# 67438     fit   342644       34c   247125   117.0    10.0          party
# 69476     fit    61837       34a   247125   145.0    10.0          party
# 79367     fit   915964       36d   247125   165.0    10.0           date
# 79991     fit   975142       34a   247125   130.0     8.0           date
# 84930     fit   451826      32d+   247125   124.0     8.0           date
# 86488     fit   229862       34d   247125   120.0     6.0          party
# 89800     fit    24196      32dd   247125   140.0     8.0          party
# 90261     fit   400495       34b   247125   130.0    10.0           date
# 92424   large   250268       34a   247125   125.0     8.0          party
# 93869     fit    57128      36d+   247125   180.0    10.0        wedding
# 96848   small   780668       36d   247125   172.0     6.0          party
# 100339    fit   894816       38c   247125   180.0     2.0          party
# 102411    fit   379501       36a   247125   165.0     8.0          party
# 107282  large   684270       34b   247125   135.0     8.0          other
# 114244    fit   599639       34b   247125   145.0    10.0  formal affair
# 116301  small   696371       34d   247125   135.0     8.0          party
# 117491    fit   615145       34d   247125   130.0    10.0           date
# 120433  large   426947       34a   247125   125.0     8.0  formal affair
# 122505    fit   622981       32a   247125   135.0     8.0        wedding
# 128756    fit   169978       34d   247125   150.0     8.0           date
# 131251    fit   735087       34h   247125   185.0    10.0          party
# 135739    fit   241998       32c   247125   105.0    10.0          party
# 136780    fit   163877       34c   247125   152.0    10.0           date
# 137634    fit   499011       34b   247125   140.0    10.0          party
# 137864    fit     3652       34b   247125   114.0    10.0          party
# 141043    fit    26760       32b   247125   140.0    10.0        wedding
# 142168  small   291899       36b   247125   145.0    10.0          party
# 145184    fit   345240       38d   247125   185.0    10.0        wedding
# 146897    fit   302060       36d   247125   165.0    10.0          party
# 153894    fit   301312       34d   247125   150.0     8.0          party
# 154043  small   585359      36d+   247125   150.0    10.0          party
# 160105    fit   796536       32b   247125   140.0     8.0  formal affair
# 172044    fit   859257       36c   247125   120.0     8.0  formal affair
# 174410  small   593075       32a   247125   100.0    10.0  formal affair
# 174568    fit   250619       34a   247125   125.0    10.0          party
# 188335    fit   724298       34c   247125   140.0    10.0          party
# 188834    fit   843457       34c   247125   150.0    10.0          party
#
#                                               review_text          body type  \
# 12254   I wore this dress to celebrate NYE in New York...           athletic
# 17022   Fit perfectly, really warm, thick material, gr...          hourglass
# 22418   Beautiful dress, I wore it for my husbands bir...          hourglass
# 26090                  This dress was great, perfect LBD!          hourglass
# 38891   Pros - material/details are beautiful, hugs th...             petite
# 39212   Runs a bit short, but otherwise the cut-outs a...          hourglass
# 47674   Size down if between sizes. It looks better ti...          hourglass
# 52220   Sleeves were a little long, but I rolled them ...               pear
# 56636   Sadly I was unable to wear it because it runs ...           athletic
# 58304   Wonderful dress for a February wedding.  Very ...  straight & narrow
# 59810   Gorgeous dress. Jaws dropped when I tried it o...  straight & narrow
# 61591   The dress hugs every curve but also leaves not...               pear
# 62800   Great fit. Super comfortable. Long sleeves hel...             petite
# 67438   It fits very well. Thick fabric with a lot of ...          full bust
# 69476   I loved this dress!  I am pear shaped and I th...               pear
# 79367   First of all let me say neoprene is my new fav...          hourglass
# 79991   The cutouts on the front venture a bit low if ...  straight & narrow
# 84930   Loved this dress! It stretchy and easy to wear...          hourglass
# 86488   When I saw this dress on this site, I thought ...               pear
# 89800   Probably not the best choice for a pear shape ...               pear
# 90261   Love this dress. If in between, order a size u...           athletic
# 92424   Wore this dress to a Halloween-themed wedding/...  straight & narrow
# 93869   This was my first experience with Rent the Run...          hourglass
# 96848                  A bit to tight so I didn't wear it           athletic
# 100339  This was a very cute dress. The material was s...          hourglass
# 102411  Pros: Got A LOT of compliments on the dress. I...               pear
# 107282  Ran a little larger than I expected - I usuall...           athletic
# 114244  Great dress! Warm, thick material. Wore a size...           athletic
# 116301  Definitely runs small. I got the small and med...          hourglass
# 117491  I wore this dress for an anniversary date nigh...          hourglass
# 120433  The dress ran large; I usually wear a small an...           athletic
# 122505  I should have worn the medium for fit, but the...               pear
# 128756  I actually end up wearing the other dress inst...               pear
# 131251  Great dress!!  Its even nicer in person.  I lo...          hourglass
# 135739  I didn't wear it because it was super hot in L...             petite
# 136780  Very nice material, especially for the colder ...           athletic
# 137634  I am usually a size medium, but it wasn't avai...           athletic
# 137864  I rented this for my nieces bachelorette dinne...             petite
# 141043  I rented this dress to wear to the rehearsal d...               pear
# 142168  I rented this dress for my husband's work even...          hourglass
# 145184  I received this dress because the Tibi tunic I...              apple
# 146897  I wore this dress for a new years party in Chi...          hourglass
# 153894  Loved it!The dress is slimming, the cutouts ar...          hourglass
# 154043  I rented this dress for a birthday party where...          full bust
# 160105  This is a really beautiful dress - that being ...               pear
# 172044  Initially ordered a medium but ended up wearin...          hourglass
# 174410  I'm pretty petite and an xs small was tight in...             petite
# 174568  The dress fit well and was a nice comfy materi...           athletic
# 188335  The material is very thick. I got a little war...          hourglass
# 188834  Wore this for my holiday party .. The medium w...          hourglass
#
#                                            review_summary category  height  \
# 12254                         Perfect for a winter event!    dress      71
# 17022   Everyone loved the dress, it was for my 21st b...    dress      67
# 22418                         LBD with something special!    dress      62
# 26090                                            Awesome!    dress      69
# 38891                             The dress was perfect!     dress      62
# 39212                                    Beautiful dress!    dress      71
# 47674   Many compliments from gals and guys. It's so s...    dress      66
# 52220   Lots of compliments! Perfect for a work holida...    dress      68
# 56636   Love this dress  not as short as it appears. b...    dress      70
# 58304                                          Great LBD!    dress      72
# 59810                 Thick fabric, flattering silhouette    dress      68
# 61591                   Perfect for a winter date night!     dress      67
# 62800                       Received so many complements!    dress      64
# 67438   The cutout made it look really sexy.  Very fla...    dress      63
# 69476   Perfect dress to wear to an evening dinner party.    dress      68
# 79367                Great company on a Valentine's Date!    dress      69
# 79991                       This was okay, good for price    dress      69
# 84930                                     Classy but sexy    dress      64
# 86488                                              Meh...    dress      63
# 89800   Sexy, but maybe a little too sleek for this pe...    dress      69
# 90261                          Edgy look for a night out!    dress      69
# 92424                              Comfortable and classy    dress      67
# 93869   Got so many compliments!  Great dress, would d...    dress      65
# 96848                                   Beautiful details    dress      70
# 100339                                         not for me    dress      64
# 102411  Lots of Compliments, But Not a 100% Pefect Fit...    dress      67
# 107282  I wore this dress for my senior homecoming dance!    dress      64
# 114244          Photographs well and is a flattering cut!    dress      64
# 116301                       Cool details on a demure LBD    dress      66
# 117491                                       Sexy Comfort    dress      66
# 120433                         I got so many compliments!    dress      62
# 122505                           Nice for a fall wedding!    dress      62
# 128756                    Little Black Dress with a Twist    dress      69
# 131251                                           friends!    dress      63
# 135739                                               chic    dress      64
# 136780                       Loved it, very comfortable!     dress      67
# 137634                 So sexy without being over the top    dress      66
# 137864                                  Stunning cutouts!    dress      62
# 141043                       Rehearsal Dinner for Wedding    dress      66
# 142168  Classy but sexy dress...perfect for chilly wea...    dress      67
# 145184                            Gorgeous and flattering    dress      68
# 146897                Comfortable, classy and interesting    dress      68
# 153894  Stylish take on the classic LBD. Received so m...    dress      64
# 154043                       Different and unforgettable!    dress      63
# 160105                                        Great dress    dress      68
# 172044  Great dress for my daughter's high school wint...    dress      62
# 174410                         The dress was very classy.    dress      60
# 174568  So easy and convenient!  Love the service and ...    dress      66
# 188335  I loved this dress! I wore this to a friend's ...    dress      65
# 188834  Great beautiful black dress !  Received many c...    dress      68
#
#         size   age         review_date  height_inches  weight_lbs
# 12254     14  27.0     January 1, 2015             71         145
# 17022     20  24.0   December 16, 2014             67         165
# 22418     20  27.0      March 13, 2017             62         180
# 26090     14  32.0   November 29, 2016             69         155
# 38891      4  30.0   February 24, 2015             62         130
# 39212     20  31.0   February 11, 2017             71         155
# 47674      8  41.0    October 18, 2016             66         145
# 52220     14  28.0   December 23, 2014             68         135
# 56636     20  51.0        May 11, 2015             70         150
# 58304     20  35.0   February 27, 2017             72         160
# 59810      8  40.0   December 21, 2015             68         134
# 61591     14  30.0    January 20, 2016             67         148
# 62800      4  37.0    November 5, 2017             64         115
# 67438      8  65.0    December 9, 2014             63         117
# 69476     14  28.0  September 15, 2015             68         145
# 79367     14  27.0      April 10, 2015             69         165
# 79991      4  34.0    December 2, 2015             69         130
# 84930      8  29.0       June 15, 2016             64         124
# 86488      8  33.0     October 6, 2014             63         120
# 89800     14  29.0    October 29, 2014             69         140
# 90261     14  40.0      March 28, 2016             69         130
# 92424      8  31.0   November 10, 2015             67         125
# 93869     20  31.0     January 7, 2015             65         180
# 96848     20  45.0   November 22, 2015             70         172
# 100339    20  35.0   December 18, 2014             64         180
# 102411    20  30.0   December 22, 2014             67         165
# 107282     8  20.0     January 1, 2015             64         135
# 114244    20  29.0   November 27, 2016             64         145
# 116301    14  44.0   November 10, 2014             66         135
# 117491    14  33.0    October 29, 2014             66         130
# 120433     4  24.0   November 19, 2014             62         125
# 122505     8  32.0     October 9, 2016             62         135
# 128756    14  31.0   February 20, 2017             69         150
# 131251    20  36.0      April 17, 2015             63         185
# 135739     4  38.0      August 4, 2015             64         105
# 136780     8  32.0   November 23, 2014             67         152
# 137634     8  31.0     January 2, 2017             66         140
# 137864     8  56.0    January 21, 2016             62         114
# 141043    14  31.0    December 8, 2015             66         140
# 142168    20  34.0       March 8, 2016             67         145
# 145184    20  45.0     October 9, 2014             68         185
# 146897    14  32.0   February 17, 2015             68         165
# 153894    14  33.0   February 29, 2016             64         150
# 154043    20  38.0    November 6, 2015             63         150
# 160105    14  22.0      March 16, 2016             68         140
# 172044     8  42.0    February 6, 2016             62         120
# 174410     4  25.0  September 21, 2014             60         100
# 174568     8  35.0    February 1, 2016             66         125
# 188335    14  29.0    February 9, 2015             65         140
# 188834    14  44.0   December 13, 2014             68         150
#           fit  user_id bust size  item_id  weight  rating rented for  \
# 1771      fit    45387       32a   255241   110.0    10.0       work
# 11466     fit   923427       32c   255241   112.0     8.0   everyday
# 16650   large   582668       34b   255241   120.0    10.0   everyday
# 39218   large   175974       34a   255241   140.0    10.0       work
# 58680     fit   647640       34b   255241   150.0    10.0   everyday
# 114885    fit   724166       34b   255241   120.0     8.0   everyday
# 159153  large   556687       34b   255241   135.0     8.0   everyday
# 179401  large   665724       34d   255241   110.0    10.0   everyday
#
#                                               review_text  body type  \
# 1771    This dress was perfect to throw on for work. I...  hourglass
# 11466   I believe this dress runs true to size, but I ...     petite
# 16650   I really liked this dress.  I had previously r...   athletic
# 39218   So many compliments. Absolutely beautiful dres...   athletic
# 58680   The bottom came slightly wrinkled but not noti...  hourglass
# 114885  The fit was as expected, a little shorter than...  hourglass
# 159153  The material is nice and feels fancy.  I wore ...   athletic
# 179401  Sweet dress for a summer day! Running on the l...  hourglass
#
#                                    review_summary category  height  size  \
# 1771                               Classic Dress!    dress      63     4
# 11466                                  Cute dress    dress      62     4
# 16650                     Really fun flirty dress    dress      65     4
# 39218                            Compliment city     dress      65    14
# 58680                 Absolutely gorgeous dress.     dress      65    14
# 114885              Great white dress for summer!    dress      66     4
# 159153  Despite how big it is, it's super cute.      dress      67     8
# 179401                             Stylist Review    dress      61     8
#
#          age      review_date  height_inches  weight_lbs
# 1771    24.0  August 30, 2016             63         110
# 11466   36.0     July 5, 2017             62         112
# 16650   30.0     July 6, 2016             65         120
# 39218   24.0    June 15, 2016             65         140
# 58680   22.0     June 1, 2016             65         150
# 114885  28.0    June 30, 2016             66         120
# 159153  37.0    July 26, 2017             67         135
# 179401  23.0   April 20, 2016             61         110

# %%
import pandas as pd
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity


product_df['combined_text'] = product_df['review_text'] + ' ' + product_df['review_summary']

tokenized_text = product_df['combined_text'].apply(lambda x: x.split())

model = Word2Vec(sentences=tokenized_text, vector_size=100, window=5, min_count=1, workers=4)


def average_word_vectors(words, model, vocabulary, num_features):
    feature_vector = np.zeros((num_features,), dtype="float64")
    nwords = 0.
    for word in words:
        if word in vocabulary:
            nwords = nwords + 1.
            feature_vector = np.add(feature_vector, model.wv[word])
    if nwords:
        feature_vector = np.divide(feature_vector, nwords)
    return feature_vector

word_vectors = np.array([average_word_vectors(review, model, model.wv.index_to_key, 100) for review in tokenized_text])

item_item_similarity = cosine_similarity(word_vectors, word_vectors)

# %%
item_id = 100
similar_items_indices = item_item_similarity[item_id].argsort()[::-1][1:6]


similar_items = product_df.iloc[similar_items_indices]

print(similar_items)

# %%
unique_user_ids = len(df['user_id'].unique())
print(unique_user_ids)
